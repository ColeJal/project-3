# %%
import pandas as pd
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
summary=pd.read_csv('data/1990_2022_summary.csv')

# %%
pip install geopandas
# Out:
# ...
#   Running setup.py clean for fiona
# Failed to build fiona
# ...
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
# ...

# %%
summary
# Out:
#                country      year  total_deaths  total_affected  \
# 0          Afghanistan  385371.0         23398        33810381
# 1              Albania   60242.0           103         1171262
# 2              Algeria  126309.0          4258          833866
# 3       American Samoa    8021.0            40           25563
# 4               Angola  136585.0          5158         6274389
# ..                 ...       ...           ...             ...
# 216  Wallis and Futuna    4005.0             5            1272
# 217              Yemen  116569.0          2371         1845637
# 218         Yugoslavia    3980.0             0               0
# 219             Zambia   90278.0          1361        12323050
# 220           Zimbabwe  104391.0          7593        27553177
#
#      reconstruction_costs_('000_us$)  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# ...

# %%
geojson=pd.read_json
